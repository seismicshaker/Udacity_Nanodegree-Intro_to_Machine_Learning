# %% [markdown]
# # Introduction
#
# In this project, you will build a neural network of your own design to evaluate the CIFAR-10 dataset.
# Our target accuracy is 70%, but any accuracy over 50% is a great start.
# Some of the benchmark results on CIFAR-10 include:
#
# 78.9% Accuracy | [Deep Belief Networks; Krizhevsky, 2010](https://www.cs.toronto.edu/~kriz/conv-cifar10-aug2010.pdf)
#
# 90.6% Accuracy | [Maxout Networks; Goodfellow et al., 2013](https://arxiv.org/pdf/1302.4389.pdf)
#
# 96.0% Accuracy | [Wide Residual Networks; Zagoruyko et al., 2016](https://arxiv.org/pdf/1605.07146.pdf)
#
# 99.0% Accuracy | [GPipe; Huang et al., 2018](https://arxiv.org/pdf/1811.06965.pdf)
#
# 98.5% Accuracy | [Rethinking Recurrent Neural Networks and other Improvements for ImageClassification; Nguyen et al., 2020](https://arxiv.org/pdf/2007.15161.pdf)
#
# Research with this dataset is ongoing. Notably, many of these networks are quite large and quite expensive to train.
#
# ## Imports

# %%
## This cell contains the essential imports you will need – DO NOT CHANGE THE CONTENTS! ##
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import numpy as np

# Set the random seed to reproduce same results
torch.manual_seed(13) 
np.random.seed(13)

# %% [markdown]
# ## Load the Dataset
#
# Specify your transforms as a list first.
# The transforms module is already loaded as `transforms`.
#
# CIFAR-10 is fortunately included in the torchvision module.
# Then, you can create your dataset using the `CIFAR10` object from `torchvision.datasets` ([the documentation is available here](https://pytorch.org/docs/stable/torchvision/datasets.html#cifar)).
# Make sure to specify `download=True`!
#
# Once your dataset is created, you'll also need to define a `DataLoader` from the `torch.utils.data` module for both the train and the test set.

# %%
# Transform and Dataloader parameters
batch_size = 15
rotation_angle = 25

# Define transforms
traintransform = transforms.Compose([transforms.RandomHorizontalFlip(),
                                     transforms.RandomRotation(degrees=rotation_angle),
                                     transforms.ToTensor(),
                                     transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5)),
                                     ])
testtransform = transforms.Compose([transforms.ToTensor(),
                                    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5)),
                                    ])


# Define training data
trainset = torchvision.datasets.CIFAR10(root='./data', train=True,
                                        download=True, transform=traintransform)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=batch_size,
                                          shuffle=True, num_workers=2)
N_trainloader = len(trainloader)

# Define test data
testset = torchvision.datasets.CIFAR10(root='./data', train=False,
                                       download=True, transform=testtransform)
testloader = torch.utils.data.DataLoader(testset, batch_size=batch_size,
                                         shuffle=False, num_workers=2)
N_testloader = len(testloader)

# The 10 classes in the dataset
classes = ('plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck')
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %% [markdown]
# ## Explore the Dataset
# Using matplotlib, numpy, and torch, explore the dimensions of your data.
#
# You can view images using the `show5` function defined below – it takes a data loader as an argument.
# Remember that normalized images will look really weird to you! You may want to try changing your transforms to view images.
# Typically using no transforms other than `toTensor()` works well for viewing – but not as well for training your network.
# If `show5` doesn't work, go back and check your code for creating your data loaders and your training/test sets.

# %%
def show5(img_loader):
    dataiter = iter(img_loader)
    
    batch = next(dataiter)
    labels = batch[1][0:5]
    images = batch[0][0:5]
    for i in range(5):
        print(classes[labels[i]])

        image = images[i].numpy()/2 +0.5 #unnormalize
        plt.imshow(image.T)
        plt.show()

# %%
# Explore data
show5(trainloader)
# Out:
# deer
# ship
# frog
# horse
# bird

# %% [markdown]
# ## Build your Neural Network
# Using the layers in `torch.nn` (which has been imported as `nn`) and the `torch.nn.functional` module (imported as `F`), construct a neural network based on the parameters of the dataset.
# Feel free to construct a model of any architecture – feedforward, convolutional, or even something more advanced!

# %%
model = nn.Sequential(nn.Flatten(),
                      nn.Linear(3*32*32, 128), nn.ReLU(),
                      nn.Linear(128, 64), nn.ReLU(),nn.Dropout(0.1),
                      nn.Linear(64, 10),
                      
                      nn.LogSoftmax(dim=1))

# %% [markdown]
# Specify a loss function and an optimizer, and instantiate the model.
#
# If you use a less common loss function, please note why you chose that loss function in a comment.

# %%
## Define a loss function
criterion =  nn.NLLLoss()

## Define an optimizer
optimizer = optim.SGD(model.parameters(), lr=0.001)

# %% [markdown]
# ## Running your Neural Network
# Use whatever method you like to train your neural network, and ensure you record the average loss at each epoch.
# Don't forget to use `torch.device()` and the `.to()` method for both your model and your data if you are using GPU!
#
# If you want to print your loss during each epoch, you can use the `enumerate` function and print the loss after a set number of batches. 250 batches works well for most people!

# %%
# Initialize
epochs = 30
train_losses, test_losses, test_accuracies = [], [],[]

# Train model
for e in range(epochs):
    train_loss = 0
    for n, data in enumerate(trainloader):
        if n==0: print(f'Epoch: {e+1}/{epochs}:')
        
        # get inputs
        images, labels = data
        
        # zero the parameter gradients    
        optimizer.zero_grad()
        
        # forward + backward + optimize
        log_ps= model.forward(images)
        loss  = criterion(log_ps, labels)
        loss.backward()
        optimizer.step()
        
        train_loss += loss.item()
    else: test_loss, test_acc = 0,0 
        
    model.eval()
    # Turn off gradients for validation, saves memory and computations
    with torch.no_grad():
        for images, labels in testloader:
            log_ps = model.forward(images)
            test_loss += criterion(log_ps, labels)
            
            # calculate accuracy
            ps = torch.exp(log_ps)
            top_p, top_class = ps.topk(1, dim=1)
            equals = top_class == labels.view(*top_class.shape)
            test_acc += torch.mean(equals.type(torch.FloatTensor)).item()
    model.train()

    # Average out the statistics
    train_loss = train_loss/N_trainloader
    test_loss = test_loss/N_testloader
    test_acc  = test_acc/N_testloader

    # Print statistics
    print(f'\tTraining Loss: {train_loss:.3f}\n',
          f'\tTest Loss:     {test_loss:.3f},\tTest Accuracy: {test_acc*100:.1f}%')
    # Save statistics
    train_losses.append(train_loss)
    test_losses.append(test_loss)
    test_accuracies.append(test_acc)

        
print('Finished Training')
# Out:
# Epoch: 1/30:
# 	Training Loss: 2.172
#  	Test Loss:     2.076,	Test Accuracy: 28.9%
# Epoch: 2/30:
# 	Training Loss: 1.974
#  	Test Loss:     1.958,	Test Accuracy: 33.0%
# Epoch: 3/30:
# 	Training Loss: 1.888
#  	Test Loss:     1.874,	Test Accuracy: 36.1%
# Epoch: 4/30:
# 	Training Loss: 1.832
#  	Test Loss:     1.819,	Test Accuracy: 37.2%
# Epoch: 5/30:
# 	Training Loss: 1.793
#  	Test Loss:     1.774,	Test Accuracy: 38.9%
# Epoch: 6/30:
# 	Training Loss: 1.762
#  	Test Loss:     1.738,	Test Accuracy: 39.7%
# Epoch: 7/30:
# 	Training Loss: 1.735
#  	Test Loss:     1.708,	Test Accuracy: 40.6%
# Epoch: 8/30:
# 	Training Loss: 1.710
#  	Test Loss:     1.679,	Test Accuracy: 42.1%
# Epoch: 9/30:
# 	Training Loss: 1.686
#  	Test Loss:     1.662,	Test Accuracy: 42.4%
# Epoch: 10/30:
# 	Training Loss: 1.668
#  	Test Loss:     1.634,	Test Accuracy: 43.3%
# Epoch: 11/30:
# 	Training Loss: 1.647
#  	Test Loss:     1.622,	Test Accuracy: 43.4%
# Epoch: 12/30:
# 	Training Loss: 1.630
#  	Test Loss:     1.603,	Test Accuracy: 44.3%
# Epoch: 13/30:
# 	Training Loss: 1.613
#  	Test Loss:     1.594,	Test Accuracy: 44.4%
# Epoch: 14/30:
# 	Training Loss: 1.599
#  	Test Loss:     1.584,	Test Accuracy: 44.7%
# Epoch: 15/30:
# 	Training Loss: 1.587
#  	Test Loss:     1.570,	Test Accuracy: 45.2%
# Epoch: 16/30:
# 	Training Loss: 1.574
#  	Test Loss:     1.555,	Test Accuracy: 45.7%
# Epoch: 17/30:
# 	Training Loss: 1.563
#  	Test Loss:     1.547,	Test Accuracy: 46.0%
# Epoch: 18/30:
# 	Training Loss: 1.550
#  	Test Loss:     1.537,	Test Accuracy: 46.1%
# Epoch: 19/30:
# 	Training Loss: 1.542
#  	Test Loss:     1.529,	Test Accuracy: 46.5%
# Epoch: 20/30:
# 	Training Loss: 1.533
#  	Test Loss:     1.518,	Test Accuracy: 46.6%
# Epoch: 21/30:
# 	Training Loss: 1.522
#  	Test Loss:     1.509,	Test Accuracy: 47.1%
# Epoch: 22/30:
# 	Training Loss: 1.515
#  	Test Loss:     1.500,	Test Accuracy: 47.1%
# Epoch: 23/30:
# 	Training Loss: 1.506
#  	Test Loss:     1.495,	Test Accuracy: 47.3%
# Epoch: 24/30:
# 	Training Loss: 1.498
#  	Test Loss:     1.489,	Test Accuracy: 47.5%
# Epoch: 25/30:
# 	Training Loss: 1.487
#  	Test Loss:     1.474,	Test Accuracy: 48.1%
# Epoch: 26/30:
# 	Training Loss: 1.480
#  	Test Loss:     1.473,	Test Accuracy: 48.0%
# Epoch: 27/30:
# 	Training Loss: 1.473
#  	Test Loss:     1.468,	Test Accuracy: 48.2%
# Epoch: 28/30:
# 	Training Loss: 1.468
#  	Test Loss:     1.455,	Test Accuracy: 48.4%
# Epoch: 29/30:
# 	Training Loss: 1.460
#  	Test Loss:     1.452,	Test Accuracy: 49.0%
# Epoch: 30/30:
# 	Training Loss: 1.453
#  	Test Loss:     1.453,	Test Accuracy: 49.0%
# Finished Training

# %% [markdown]
# Plot the training loss (and validation loss/accuracy, if recorded).

# %%
plt.plot(train_losses, label='Training loss')
plt.plot(test_losses, label='Validation loss')
plt.legend(frameon=False)

# %% [markdown]
# ## Testing your model
# Using the previously created `DataLoader` for the test set, compute the percentage of correct predictions using the highest probability prediction.
#
# If your accuracy is over 70%, great work!
# This is a hard task to exceed 70% on.
#
# If your accuracy is under 45%, you'll need to make improvements.
# Go back and check your model architecture, loss function, and optimizer to make sure they're appropriate for an image classification task.

# %%
test_model = model

test_model.eval()
# Turn off gradients for validation, saves memory and computations
with torch.no_grad():
    for images, labels in testloader:
        log_ps = model.forward(images)
        test_loss += criterion(log_ps, labels)
            
        # calculate accuracy
        ps = torch.exp(log_ps)
        top_p, top_class = ps.topk(1, dim=1)
        equals = top_class == labels.view(*top_class.shape)
        test_acc += torch.mean(equals.type(torch.FloatTensor)).item()
    test_acc  = test_acc/N_testloader
    print("Test Accuracy: {:.1f}%".format(test_acc*100))
# Out:
# Test Accuracy: 49.1%

# %% [markdown]
# ## Saving your model
# Using `torch.save`, save your model for future loading.

# %%
torch.save(model.state_dict(), './final')

# %% [markdown]
# ## Make a Recommendation
#
# Based on your evaluation, what is your recommendation on whether to build or buy? Explain your reasoning below.

# %% [markdown]
# > I was able to build a relatively simple Neural Network model that could classify CIFAR-10 images with a 49% accuracy using laptop CPU. Base on the observed convergence of train error and testing error, I am sure that further epoch iterations could increase the accuracy. I would reccommend either a computer with GPU power or investing
